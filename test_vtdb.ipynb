# %%
from src.vector_store.chroma import ChromaVectorStore
from src.config import DataPaths, CollectionNames

# %%
chromaVectorStore = ChromaVectorStore()
dataPath = DataPaths()
collectionNames = CollectionNames()

# %%
client = chromaVectorStore.client
print(client.list_collections())
# Out:
# []

# %%
laptop_file = dataPath.FINAL_LAPTOP_DATA
csbh_file = dataPath.FINAL_CSBH_DATA
csdt_file = dataPath.FINAL_CSDT_DATA
csvc_file = dataPath.FINAL_CSVC_DATA

# %%
laptop_cll_name = collectionNames.LAPTOP_COLLECTION_NAME
csbh_cll_name = collectionNames.CSBH_COLLECTION_NAME
csdt_cll_name = collectionNames.CSDT_COLLECTION_NAME
csvc_cll_name = collectionNames.CSVC_COLLECTION_NAME

# %%
with open(csbh_file, "r", encoding='utf-8') as f:
    csbh_data = f.read() 

csbh_vector_store = chromaVectorStore.create_collection(collection_name= csbh_cll_name, text= csbh_data)

# %%
query = "chính sách bảo hành khi lỗi của người dùng thì như thế nào"
result = chromaVectorStore.similar_search(vector_store= csbh_vector_store , query= query)

# %%
print(result)
# Out:
# [Document(id='2d980aa3-9406-4d48-a6b2-6ec0ca7e1397', metadata={'chunk_id': 4}, page_content='- Sản phẩm bị lỗi do thiên tai (lũ lụt, hỏa hoạn, nguồn điện không bình thường, sai điện áp quy định…) hoặc hao mòn do môi trường gây ra.\n- Sản phẩm bị hư hỏng do lỗi người sử dụng như biến dạng vật lý như trầy, xước, lồi, lõm, móp, méo, nứt, vỡ, bị mốc, hoen rỉ, ẩm ướt, chất lỏng, côn trùng, chuột, bọ xâm nhập, ố vàng, mờ chữ, viết chữ không tẩy được…\n- Các sản phẩm Hãng sản xuất, Nhà cung cấp thông báo từ chối bảo hành do vi phạm các điều kiện bảo hành theo chính sách của hãng và nhà cung cấp.'), Document(id='69b0b865-81fa-446c-9f9f-1d58b6f14a67', metadata={'chunk_id': 2}, page_content='- Sản phẩm phát sinh lỗi trong quá trình sử dụng do nhà sản xuất như linh kiện, lỗi kỹ thuật.\nLưu ý:\n- Các điều kiện bảo hành cụ thể có thể thay đổi tùy theo từng nhà sản xuất và nhà cung cấp sản phẩm.\n- Tham khảo chính sách bảo hành của Nhà sản xuất trước khi sử dụng sản phẩm.\n## 3.\xa0SẢN PHẨM KHÔNG ĐỦ ĐIỀU KIỆN BẢO HÀNH\n- Hết thời hạn bảo hành ghi trên tem trên phiếu và biên bản bàn giao thiết bị.\n- Sản phẩm không đầy đủ các thiết bị, linh kiện đi kèm bắt buộc (ví dụ: receiver, adapter…).'), Document(id='6dd74ad1-e769-45d6-8b19-7063c7c2b654', metadata={'chunk_id': 6}, page_content='- Tất cả sản phẩm hư hỏng, sẽ được gửi cho Nhà sản xuất hoặc đơn vị được Nhà sản xuất uỷ quyền để bảo hành theo đúng chính sách bảo hành của Nhà sản xuất đưa ra. An Khang Computer không chịu trách nhiệm nếu Nhà sản xuất hoặc đơn vị được Nhà sản xuất ủy quyền từ chối bảo hành.')]

# %%
client.list_collections()
# Out:
# [Collection(name=csdt_collection),
#  Collection(name=csvc_collection),
#  Collection(name=csbh_collection),
#  Collection(name=laptop_collection)]

# %%
with open(csdt_file, "r", encoding='utf-8') as f:
    csdt_data = f.read() 

csdt_vector_store = chromaVectorStore.create_collection(collection_name= csdt_cll_name, text= csdt_data)

# %%
with open(csvc_file, "r", encoding='utf-8') as f:
    csvc_data = f.read() 

csvc_vector_store = chromaVectorStore.create_collection(collection_name= csvc_cll_name, text= csvc_data)

# %%
with open(laptop_file, "r", encoding='utf-8') as f:
    laptop_data = f.read() 

laptop_vector_store = chromaVectorStore.create_collection(collection_name= laptop_cll_name, text= laptop_data)

# %%
hihi = chromaVectorStore.load_collection(collection_name= csbh_cll_name)

# %%
client.list_collections()
# Out:
# [Collection(name=csdt_collection),
#  Collection(name=csvc_collection),
#  Collection(name=csbh_collection),
#  Collection(name=laptop_collection)]

# %%
hihi.similarity_search(query=query)
# Out:
# [Document(id='2d980aa3-9406-4d48-a6b2-6ec0ca7e1397', metadata={'chunk_id': 4}, page_content='- Sản phẩm bị lỗi do thiên tai (lũ lụt, hỏa hoạn, nguồn điện không bình thường, sai điện áp quy định…) hoặc hao mòn do môi trường gây ra.\n- Sản phẩm bị hư hỏng do lỗi người sử dụng như biến dạng vật lý như trầy, xước, lồi, lõm, móp, méo, nứt, vỡ, bị mốc, hoen rỉ, ẩm ướt, chất lỏng, côn trùng, chuột, bọ xâm nhập, ố vàng, mờ chữ, viết chữ không tẩy được…\n- Các sản phẩm Hãng sản xuất, Nhà cung cấp thông báo từ chối bảo hành do vi phạm các điều kiện bảo hành theo chính sách của hãng và nhà cung cấp.'),
#  Document(id='69b0b865-81fa-446c-9f9f-1d58b6f14a67', metadata={'chunk_id': 2}, page_content='- Sản phẩm phát sinh lỗi trong quá trình sử dụng do nhà sản xuất như linh kiện, lỗi kỹ thuật.\nLưu ý:\n- Các điều kiện bảo hành cụ thể có thể thay đổi tùy theo từng nhà sản xuất và nhà cung cấp sản phẩm.\n- Tham khảo chính sách bảo hành của Nhà sản xuất trước khi sử dụng sản phẩm.\n## 3.\xa0SẢN PHẨM KHÔNG ĐỦ ĐIỀU KIỆN BẢO HÀNH\n- Hết thời hạn bảo hành ghi trên tem trên phiếu và biên bản bàn giao thiết bị.\n- Sản phẩm không đầy đủ các thiết bị, linh kiện đi kèm bắt buộc (ví dụ: receiver, adapter…).'),
#  Document(id='6dd74ad1-e769-45d6-8b19-7063c7c2b654', metadata={'chunk_id': 6}, page_content='- Tất cả sản phẩm hư hỏng, sẽ được gửi cho Nhà sản xuất hoặc đơn vị được Nhà sản xuất uỷ quyền để bảo hành theo đúng chính sách bảo hành của Nhà sản xuất đưa ra. An Khang Computer không chịu trách nhiệm nếu Nhà sản xuất hoặc đơn vị được Nhà sản xuất ủy quyền từ chối bảo hành.'),
#  Document(id='ba8f5b9e-776e-4c9a-966b-963af3520bbe', metadata={'chunk_id': 0}, page_content='# CHÍNH SÁCH BẢO HÀNH\n## 1.\xa0LIÊN HỆ BẢO HÀNH SẢN PHẨM\nKhi có nhu cầu bảo hành sản phẩm, Quý khách hàng vui lòng liên hệ với An Khang Computer qua các hình thức sau:\n- Gọi tổng đài 1900 2655 (nhánh 106).\n- Gửi tin nhắn trực tiếp tại website hoặc fanpage.\n- Mang sản phẩm trực tiếp đến Trung tâm bảo hành của An Khang Computer: số 25 Yên Lãng – Đống Đa – Hà Nội.\n## 2. ĐIỀU KIỆN BẢO HÀNH')]
